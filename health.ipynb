# %%
import pandas as pd

df = pd.read_csv('./backend/Assets/DiseaseData.csv')

df.head()
# Out:
# C:\Users\spenc\AppData\Local\Temp\ipykernel_42984\925928479.py:3: DtypeWarning: Columns (8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./backend/Assets/DiseaseData.csv')
#    Year  LocationName DataSource               Category  \
# 0  2021          1001      BRFSS             Prevention
# 1  2021          1001      BRFSS        Health Outcomes
# 2  2021          1001      BRFSS  Health Risk Behaviors
# 3  2021          1001      BRFSS        Health Outcomes
# 4  2021          1001      BRFSS             Prevention
#
#                                              Measure Data_Value_Unit  \
# 0  Current lack of health insurance among adults ...               %
# 1             Arthritis among adults aged >=18 years               %
# 2        Binge drinking among adults aged >=18 years               %
# 3   High blood pressure among adults aged >=18 years               %
# 4  Taking medicine for high blood pressure contro...               %
#
#     Data_Value_Type  Data_Value Data_Value_Footnote_Symbol  \
# 0  Crude prevalence         4.1                        NaN
# 1  Crude prevalence        33.7                        NaN
# 2  Crude prevalence        15.6                        NaN
# 3  Crude prevalence        33.8                        NaN
# 4  Crude prevalence        78.9                        NaN
#
#   Data_Value_Footnote  Low_Confidence_Limit  High_Confidence_Limit  \
# 0                 NaN                   3.4                    5.0
# 1                 NaN                  30.1                   37.4
# 2                 NaN                  13.2                   18.2
# 3                 NaN                  30.2                   37.4
# 4                 NaN                  75.7                   81.8
#
#    TotalPopulation                       Geolocation  LocationID CategoryID  \
# 0            16769  POINT (-72.62581515 42.06255509)        1001    PREVENT
# 1            16769  POINT (-72.62581515 42.06255509)        1001    HLTHOUT
# 2            16769  POINT (-72.62581515 42.06255509)        1001    RISKBEH
# 3            16769  POINT (-72.62581515 42.06255509)        1001    HLTHOUT
# 4            16769  POINT (-72.62581515 42.06255509)        1001    PREVENT
#
#    MeasureId DataValueTypeID   Short_Question_Text
# 0    ACCESS2          CrdPrv      Health Insurance
# 1  ARTHRITIS          CrdPrv             Arthritis
# 2      BINGE          CrdPrv        Binge Drinking
# 3     BPHIGH          CrdPrv   High Blood Pressure
# 4      BPMED          CrdPrv  Taking BP Medication

# %%
# df2 = df.pivot(index='LocationName', columns='Short_Question_Text', values='Data_Value').reset_index()

df.head(10)
# Out:
# Short_Question_Text  LocationName  All Teeth Lost  Annual Checkup  \
# 0                            1001            13.3            74.5
# 1                            1002            12.4            69.2
# 2                            1003             NaN            63.1
# 3                            1005            12.1            75.7
# 4                            1007             9.2            71.7
# 5                            1008            12.2            73.1
# 6                            1009            14.1            71.6
# 7                            1010            11.9            73.3
# 8                            1011            12.5            72.7
# 9                            1012            11.5            72.7
#
# Short_Question_Text  Any Disability  Arthritis  Binge Drinking  COPD  \
# 0                              31.5       33.7            15.6   7.3
# 1                              26.5       18.9            17.3   5.1
# 2                              35.2        5.5            19.3   3.4
# 3                              24.9       26.4            17.4   6.4
# 4                              21.3       25.2            18.1   5.3
# 5                              28.8       32.3            17.1   7.0
# 6                              30.5       30.2            17.7   7.0
# 7                              28.6       32.2            16.9   6.9
# 8                              28.2       31.3            17.4   6.9
# 9                              25.1       28.8            17.1   6.7
#
# Short_Question_Text  Cancer (except skin)  Cervical Cancer Screening  \
# 0                                     9.1                       85.6
# 1                                     4.9                       73.5
# 2                                     0.7                       46.7
# 3                                     7.4                       86.2
# 4                                     6.9                       85.4
# 5                                     7.7                       85.9
# 6                                     7.1                       85.4
# 7                                     7.8                       86.9
# 8                                     7.7                       86.1
# 9                                     7.8                       84.3
#
# Short_Question_Text  Cholesterol Screening  ...  Mental Health  \
# 0                                     89.1  ...           16.3
# 1                                     78.0  ...           20.2
# 2                                     56.0  ...           33.8
# 3                                     88.3  ...           16.2
# 4                                     89.0  ...           14.7
# 5                                     89.2  ...           16.7
# 6                                     86.6  ...           18.6
# 7                                     89.4  ...           16.7
# 8                                     88.8  ...           16.4
# 9                                     89.0  ...           15.2
#
# Short_Question_Text  Mobility Disability  Obesity  Physical Health  \
# 0                                   14.3     31.8             11.3
# 1                                    9.2     23.3              8.9
# 2                                    4.0     22.2              8.5
# 3                                   10.7     31.4             10.0
# 4                                    9.4     25.7              8.9
# 5                                   12.7     33.3             11.1
# 6                                   13.0     33.9             11.4
# 7                                   12.7     33.7             11.0
# 8                                   12.4     32.3             10.9
# 9                                   11.8     26.8             10.5
#
# Short_Question_Text  Physical Inactivity  Self-care Disability  \
# 0                                   23.4                   3.5
# 1                                   19.9                   2.9
# 2                                   22.7                   2.2
# 3                                   19.9                   2.9
# 4                                   17.3                   2.5
# 5                                   22.0                   3.3
# 6                                   23.1                   3.5
# 7                                   21.8                   3.3
# 8                                   21.7                   3.2
# 9                                   20.3                   3.1
#
# Short_Question_Text  Sleep <7 hours  Stroke  Taking BP Medication  \
# 0                              33.5     3.3                  78.9
# 1                              30.1     2.1                  70.1
# 2                              33.1     0.7                  19.8
# 3                              32.5     2.7                  74.5
# 4                              30.0     2.3                  73.3
# 5                              34.5     2.8                  76.8
# 6                              35.3     2.8                  74.8
# 7                              34.4     2.8                  76.6
# 8                              33.9     2.8                  76.3
# 9                              30.7     2.8                  76.2
#
# Short_Question_Text  Vision Disability
# 0                                  4.2
# 1                                  4.4
# 2                                  6.4
# 3                                  3.4
# 4                                  3.0
# 5                                  3.7
# 6                                  4.1
# 7                                  3.8
# 8                                  3.7
# 9                                  3.6
#
# [10 rows x 38 columns]

# %%
def extract_coordinates(point_str):
    # Remove the "POINT (" prefix and ")" suffix
    coords_str = point_str.replace("POINT (", "").replace(")", "")

    # Split the string by whitespace to separate the x and y coordinates
    x_str, y_str = coords_str.split()

    # Convert the coordinates from strings to floats
    x = float(x_str)
    y = float(y_str)

    return round(x, 3), round(y, 3)

# Apply the function to each row of the DataFrame and create a new column with tuples
df[['x', 'y']] = df['Geolocation'].apply(lambda x: pd.Series(extract_coordinates(x)))

# Combine x and y coordinates into a string in the format "x,y"
# df['coords'] = df.apply(lambda row: '{},{}'.format(row['x'], row['y']), axis=1)

df.head()
# Out:
# Short_Question_Text                       Geolocation  All Teeth Lost  \
# 0                     POINT (-100.0010914 39.3319043)            12.9
# 1                    POINT (-100.0057719 31.60271604)            15.2
# 2                    POINT (-100.0072727 36.65401402)            18.1
# 3                    POINT (-100.0103039 38.09098291)            12.8
# 4                    POINT (-100.0122955 37.73694235)            18.2
#
# Short_Question_Text  Annual Checkup  Any Disability  Arthritis  \
# 0                              76.6            33.0       35.0
# 1                              73.0            33.1       29.4
# 2                              74.9            37.5       29.6
# 3                              74.3            29.8       29.7
# 4                              69.8            32.9       20.4
#
# Short_Question_Text  Binge Drinking  COPD  Cancer (except skin)  \
# 0                              14.7   8.8                  10.7
# 1                              16.6   8.6                   8.4
# 2                              13.5   8.9                   7.8
# 3                              16.6   7.3                   8.8
# 4                              17.5   6.7                   5.3
#
# Short_Question_Text  Cervical Cancer Screening  Cholesterol Screening  ...  \
# 0                                         84.6                   88.6  ...
# 1                                         79.4                   86.2  ...
# 2                                         80.0                   83.0  ...
# 3                                         84.2                   85.5  ...
# 4                                         77.7                   76.0  ...
#
# Short_Question_Text  Obesity  Physical Health  Physical Inactivity  \
# 0                       35.1             12.1                 27.1
# 1                       35.9             13.0                 27.2
# 2                       39.1             13.7                 30.7
# 3                       36.7             10.9                 25.1
# 4                       43.9             12.2                 31.8
#
# Short_Question_Text  Self-care Disability  Sleep <7 hours  Stroke  \
# 0                                     4.1            29.2     4.3
# 1                                     4.2            32.4     3.8
# 2                                     4.5            32.8     3.7
# 3                                     3.4            29.5     3.4
# 4                                     4.6            33.0     2.9
#
# Short_Question_Text  Taking BP Medication  Vision Disability        x       y
# 0                                    85.0                4.7 -100.001  39.332
# 1                                    79.2                5.4 -100.006  31.603
# 2                                    79.1                5.8 -100.007  36.654
# 3                                    81.6                4.1 -100.010  38.091
# 4                                    74.5                6.8 -100.012  37.737
#
# [5 rows x 40 columns]

# %%
""" Grabs zip code from coords """
# DO we need zip? might be too many ovelraps
# add column if so


import requests

url = "https://trueway-geocoding.p.rapidapi.com/ReverseGeocode"


x = df['coords'].head(1)[0][0]
y = df['coords'].head(1)[0][1]

coords = df['coords'].head(1)[0]

querystring = {"location":coords,"language":"en"}

headers = {
	"X-RapidAPI-Key": "01836c3714msh582bac2093a6a03p19e6abjsn2b918034e4c0",
	"X-RapidAPI-Host": "trueway-geocoding.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())

# coords
# (x,y)
# Out:
# {'results': [{'address': '8XJX+QH Penokee, KS, USA', 'postal_code': '67659', 'country': 'United States', 'region': 'Kansas', 'area': 'Graham County', 'locality': 'Penokee', 'location': {'lat': 39.332027, 'lng': -100.001021}, 'location_type': 'centroid', 'type': 'poi'}, {'address': '2200-2448 190th Ave, Penokee, KS 67659, USA', 'postal_code': '67659', 'country': 'United States', 'region': 'Kansas', 'area': 'Graham County', 'locality': 'Penokee', 'street': '190th Avenue', 'house': '2200-2448', 'location': {'lat': 39.323951, 'lng': -99.995518}, 'location_type': 'centroid', 'type': 'route'}, {'address': 'Solomon, KS, USA', 'country': 'United States', 'region': 'Kansas', 'area': 'Graham County', 'location': {'lat': 39.319249, 'lng': -100.058333}, 'location_type': 'approximate', 'type': 'admin_area'}, {'address': 'Penokee, KS 67659, USA', 'postal_code': '67659', 'country': 'United States', 'region': 'Kansas', 'area': 'Graham County', 'locality': 'Penokee', 'location': {'lat': 39.450221, 'lng': -99.968847}, 'location_type': 'approximate', 'type': 'postal_code'}, {'address': 'Graham County, KS, USA', 'country': 'United States', 'region': 'Kansas', 'area': 'Graham County', 'location': {'lat': 39.319811, 'lng': -99.812514}, 'location_type': 'approximate', 'type': 'area'}]}

# %%
df.head()
# Out:
# Short_Question_Text                       Geolocation  All Teeth Lost  \
# 0                     POINT (-100.0010914 39.3319043)            12.9
# 1                    POINT (-100.0057719 31.60271604)            15.2
# 2                    POINT (-100.0072727 36.65401402)            18.1
# 3                    POINT (-100.0103039 38.09098291)            12.8
# 4                    POINT (-100.0122955 37.73694235)            18.2
#
# Short_Question_Text  Annual Checkup  Any Disability  Arthritis  \
# 0                              76.6            33.0       35.0
# 1                              73.0            33.1       29.4
# 2                              74.9            37.5       29.6
# 3                              74.3            29.8       29.7
# 4                              69.8            32.9       20.4
#
# Short_Question_Text  Binge Drinking  COPD  Cancer (except skin)  \
# 0                              14.7   8.8                  10.7
# 1                              16.6   8.6                   8.4
# 2                              13.5   8.9                   7.8
# 3                              16.6   7.3                   8.8
# 4                              17.5   6.7                   5.3
#
# Short_Question_Text  Cervical Cancer Screening  Cholesterol Screening  ...  \
# 0                                         84.6                   88.6  ...
# 1                                         79.4                   86.2  ...
# 2                                         80.0                   83.0  ...
# 3                                         84.2                   85.5  ...
# 4                                         77.7                   76.0  ...
#
# Short_Question_Text  Physical Inactivity  Self-care Disability  \
# 0                                   27.1                   4.1
# 1                                   27.2                   4.2
# 2                                   30.7                   4.5
# 3                                   25.1                   3.4
# 4                                   31.8                   4.6
#
# Short_Question_Text  Sleep <7 hours  Stroke  Taking BP Medication  \
# 0                              29.2     4.3                  85.0
# 1                              32.4     3.8                  79.2
# 2                              32.8     3.7                  79.1
# 3                              29.5     3.4                  81.6
# 4                              33.0     2.9                  74.5
#
# Short_Question_Text  Vision Disability           x          y  \
# 0                                  4.7 -100.001091  39.331904
# 1                                  5.4 -100.005772  31.602716
# 2                                  5.8 -100.007273  36.654014
# 3                                  4.1 -100.010304  38.090983
# 4                                  6.8 -100.012295  37.736942
#
# Short_Question_Text                          x,y                    coords
# 0                     (-100.0010914, 39.3319043)   39.3319043,-100.0010914
# 1                    (-100.0057719, 31.60271604)  31.60271604,-100.0057719
# 2                    (-100.0072727, 36.65401402)  36.65401402,-100.0072727
# 3                    (-100.0103039, 38.09098291)  38.09098291,-100.0103039
# 4                    (-100.0122955, 37.73694235)  37.73694235,-100.0122955
#
# [5 rows x 42 columns]

# %%
df.drop(columns='Geolocation', inplace=True)
df.head()
# Out:
# Short_Question_Text  All Teeth Lost  Annual Checkup  Any Disability  \
# 0                              12.9            76.6            33.0
# 1                              15.2            73.0            33.1
# 2                              18.1            74.9            37.5
# 3                              12.8            74.3            29.8
# 4                              18.2            69.8            32.9
#
# Short_Question_Text  Arthritis  Binge Drinking  COPD  Cancer (except skin)  \
# 0                         35.0            14.7   8.8                  10.7
# 1                         29.4            16.6   8.6                   8.4
# 2                         29.6            13.5   8.9                   7.8
# 3                         29.7            16.6   7.3                   8.8
# 4                         20.4            17.5   6.7                   5.3
#
# Short_Question_Text  Cervical Cancer Screening  Cholesterol Screening  \
# 0                                         84.6                   88.6
# 1                                         79.4                   86.2
# 2                                         80.0                   83.0
# 3                                         84.2                   85.5
# 4                                         77.7                   76.0
#
# Short_Question_Text  Chronic Kidney Disease  ...  Obesity  Physical Health  \
# 0                                       4.0  ...     35.1             12.1
# 1                                       3.7  ...     35.9             13.0
# 2                                       3.4  ...     39.1             13.7
# 3                                       3.4  ...     36.7             10.9
# 4                                       2.9  ...     43.9             12.2
#
# Short_Question_Text  Physical Inactivity  Self-care Disability  \
# 0                                   27.1                   4.1
# 1                                   27.2                   4.2
# 2                                   30.7                   4.5
# 3                                   25.1                   3.4
# 4                                   31.8                   4.6
#
# Short_Question_Text  Sleep <7 hours  Stroke  Taking BP Medication  \
# 0                              29.2     4.3                  85.0
# 1                              32.4     3.8                  79.2
# 2                              32.8     3.7                  79.1
# 3                              29.5     3.4                  81.6
# 4                              33.0     2.9                  74.5
#
# Short_Question_Text  Vision Disability        x       y
# 0                                  4.7 -100.001  39.332
# 1                                  5.4 -100.006  31.603
# 2                                  5.8 -100.007  36.654
# 3                                  4.1 -100.010  38.091
# 4                                  6.8 -100.012  37.737
#
# [5 rows x 39 columns]

# %%
df.to_csv('./backend/Assets/diseases_cleaned.csv', index=False)
